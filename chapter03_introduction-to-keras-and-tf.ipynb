# %% [markdown]
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝 2판](https://tensorflow.blog/kerasdl2/)의 예제 코드를 담고 있습니다.
#
# <table align="left"><tr><td>
# <a href="https://colab.research.google.com/github/rickiepark/deep-learning-with-python-2nd/blob/master/chapter03_introduction-to-keras-and-tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </td></tr></table>

# %% [markdown]
# # 케라스와 텐서플로 소개

# %% [markdown]
# ## 텐서플로란?

# %% [markdown]
# ## 케라스란?

# %% [markdown]
# ## 케라스와 텐서플로의 간략한 역사

# %% [markdown]
# ## 딥러닝 작업 환경 설정하기

# %% [markdown]
# ### 주피터 노트북: 권장하는 딥러닝 실험 도구

# %% [markdown]
# ### 코랩 사용하기

# %% [markdown]
# #### 코랩 시작하기

# %% [markdown]
# #### pip로 패키지 설치하기

# %% [markdown]
# #### GPU 런타임 사용하기

# %% [markdown]
# ## 텐서플로 시작하기

# %% [markdown]
# #### 상수 텐서와 변수

# %% [markdown]
# **모두 1 또는 모두 0인 텐서**

# %%
import tensorflow as tf
x = tf.ones(shape=(2, 1))
print(x)
# Out:
# tf.Tensor(
# [[1.]
#  [1.]], shape=(2, 1), dtype=float32)

# %%
x = tf.zeros(shape=(2, 1))
print(x)
# Out:
# tf.Tensor(
# [[0.]
#  [0.]], shape=(2, 1), dtype=float32)

# %% [markdown]
# **랜덤 텐서**

# %%
x = tf.random.normal(shape=(3, 1), mean=0., stddev=1.)
print(x)
# Out:
# tf.Tensor(
# [[ 1.8296733]
#  [-0.5779236]
#  [ 0.6316653]], shape=(3, 1), dtype=float32)

# %%
x = tf.random.uniform(shape=(3, 1), minval=0., maxval=1.)
print(x)
# Out:
# tf.Tensor(
# [[0.17822397]
#  [0.83427024]
#  [0.5186788 ]], shape=(3, 1), dtype=float32)

# %% [markdown]
# **넘파이 배열에 값 할당하기**

# %%
import numpy as np
x = np.ones(shape=(2, 2))
x[0, 0] = 0.

# %% [markdown]
# **텐서플로 변수 만들기**

# %%
v = tf.Variable(initial_value=tf.random.normal(shape=(3, 1)))
print(v)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[-0.14491488],
#        [ 3.3704274 ],
#        [-2.4311619 ]], dtype=float32)>

# %% [markdown]
# **텐서플로 변수에 값 할당하기**

# %%
v.assign(tf.ones((3, 1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[1.],
#        [1.],
#        [1.]], dtype=float32)>

# %% [markdown]
# **변수 일부에 값 할당하기**

# %%
v[0, 0].assign(3.)
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[3.],
#        [1.],
#        [1.]], dtype=float32)>

# %% [markdown]
# **`assign_add` 사용하기**

# %%
v.assign_add(tf.ones((3, 1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[4.],
#        [2.],
#        [2.]], dtype=float32)>

# %% [markdown]
# #### 텐서 연산: 텐서플로에서 수학 계산하기

# %% [markdown]
# **기본적인 수학 연산**

# %%
a = tf.ones((2, 2))
b = tf.square(a)
c = tf.sqrt(a)
d = b + c
e = tf.matmul(a, b)
e *= d

# %% [markdown]
# #### GradientTape API 다시 살펴 보기

# %% [markdown]
# **`GradientTape` 사용하기**

# %%
input_var = tf.Variable(initial_value=3.)
with tf.GradientTape() as tape:
   result = tf.square(input_var)
gradient = tape.gradient(result, input_var)

# %% [markdown]
# **상수 입력 텐서와 함께 `GradientTape` 사용하기**

# %%
input_const = tf.constant(3.)
with tf.GradientTape() as tape:
   tape.watch(input_const)
   result = tf.square(input_const)
gradient = tape.gradient(result, input_const)

# %% [markdown]
# **그레이디언트 테이프를 중첩하여 이계도 그레이디언트를 계산하기**

# %%
time = tf.Variable(0.)
with tf.GradientTape() as outer_tape:
    with tf.GradientTape() as inner_tape:
        position =  4.9 * time ** 2
    speed = inner_tape.gradient(position, time)
acceleration = outer_tape.gradient(speed, time)

# %% [markdown]
# #### 엔드-투-엔드 예제: 텐서플로 선형 분류기

# %% [markdown]
# **2D 평면에 두 클래스의 랜덤한 포인트 생성하기**

# %%
num_samples_per_class = 1000
negative_samples = np.random.multivariate_normal(
    mean=[0, 3],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)
positive_samples = np.random.multivariate_normal(
    mean=[3, 0],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)

# %% [markdown]
# **두 클래스를 (2000, 2) 크기의 한 배열로 쌓기**

# %%
inputs = np.vstack((negative_samples, positive_samples)).astype(np.float32)

# %% [markdown]
# **(0과 1로 구성된) 타깃 생성하기**

# %%
targets = np.vstack((np.zeros((num_samples_per_class, 1), dtype="float32"),
                     np.ones((num_samples_per_class, 1), dtype="float32")))

# %% [markdown]
# **두 클래스의 포인트를 그래프로 그리기**

# %%
import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], inputs[:, 1], c=targets[:, 0])
plt.show()

# %% [markdown]
# **선형 분류기의 변수 만들기**

# %%
input_dim = 2
output_dim = 1
W = tf.Variable(initial_value=tf.random.uniform(shape=(input_dim, output_dim)))
b = tf.Variable(initial_value=tf.zeros(shape=(output_dim,)))

# %% [markdown]
# **정방향 패스 함수**

# %%
def model(inputs):
    return tf.matmul(inputs, W) + b

# %% [markdown]
# **평균 제곱 오차 손실 함수**

# %%
def square_loss(targets, predictions):
    per_sample_losses = tf.square(targets - predictions)
    return tf.reduce_mean(per_sample_losses)

# %% [markdown]
# **훈련 스텝 함수**

# %%
learning_rate = 0.1

def training_step(inputs, targets):
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        loss = square_loss(targets, predictions)
    grad_loss_wrt_W, grad_loss_wrt_b = tape.gradient(loss, [W, b])
    W.assign_sub(grad_loss_wrt_W * learning_rate)
    b.assign_sub(grad_loss_wrt_b * learning_rate)
    return loss

# %% [markdown]
# **배치 훈련 루프**

# %%
for step in range(40):
    loss = training_step(inputs, targets)
    print(f"{step}번째 스텝의 손실: {loss:.4f}")
# Out:
# 0번째 스텝의 손실: 5.7288
# 1번째 스텝의 손실: 0.7650
# 2번째 스텝의 손실: 0.2272
# 3번째 스텝의 손실: 0.1500
# 4번째 스텝의 손실: 0.1316
# 5번째 스텝의 손실: 0.1215
# 6번째 스텝의 손실: 0.1130
# 7번째 스텝의 손실: 0.1053
# 8번째 스텝의 손실: 0.0984
# 9번째 스텝의 손실: 0.0920
# 10번째 스텝의 손실: 0.0862
# 11번째 스텝의 손실: 0.0809
# 12번째 스텝의 손실: 0.0761
# 13번째 스텝의 손실: 0.0717
# 14번째 스텝의 손실: 0.0677
# 15번째 스텝의 손실: 0.0640
# 16번째 스텝의 손실: 0.0606
# 17번째 스텝의 손실: 0.0576
# 18번째 스텝의 손실: 0.0548
# 19번째 스텝의 손실: 0.0522
# 20번째 스텝의 손실: 0.0499
# 21번째 스텝의 손실: 0.0477
# 22번째 스텝의 손실: 0.0458
# 23번째 스텝의 손실: 0.0440
# 24번째 스텝의 손실: 0.0424
# 25번째 스텝의 손실: 0.0409
# 26번째 스텝의 손실: 0.0396
# 27번째 스텝의 손실: 0.0383
# 28번째 스텝의 손실: 0.0372
# 29번째 스텝의 손실: 0.0362
# 30번째 스텝의 손실: 0.0353
# 31번째 스텝의 손실: 0.0344
# 32번째 스텝의 손실: 0.0336
# 33번째 스텝의 손실: 0.0329
# 34번째 스텝의 손실: 0.0323
# 35번째 스텝의 손실: 0.0317
# 36번째 스텝의 손실: 0.0311
# 37번째 스텝의 손실: 0.0306
# 38번째 스텝의 손실: 0.0302
# 39번째 스텝의 손실: 0.0298

# %%
predictions = model(inputs)
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)
plt.show()

# %%
x = np.linspace(-1, 4, 100)
# 사실 100개의 x 축 좌표를 만들 필요 없이 시작과 종료 위치만 있어도 됩니다.
# x = [-1, 4]
y = - W[0] /  W[1] * x + (0.5 - b) / W[1]
plt.plot(x, y, "-r")
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)
plt.show()

# %% [markdown]
# ## 신경망의 구조: 핵심 Keras API 이해하기

# %% [markdown]
# ### 층: 딥러닝의 구성 요소

# %% [markdown]
# #### 케라스의 Layer 클래스

# %% [markdown]
# **`Layer`의 서브클래스로 구현한 `Dense` 층**

# %%
from tensorflow import keras

class SimpleDense(keras.layers.Layer):

    def __init__(self, units, activation=None):
        super().__init__()
        self.units = units
        self.activation = activation

    def build(self, input_shape):
        input_dim = input_shape[-1]
        self.W = self.add_weight(shape=(input_dim, self.units),
                                 initializer="random_normal")
        self.b = self.add_weight(shape=(self.units,),
                                 initializer="zeros")

    def call(self, inputs):
        y = tf.matmul(inputs, self.W) + self.b
        if self.activation is not None:
            y = self.activation(y)
        return y

# %%
my_dense = SimpleDense(units=32, activation=tf.nn.relu)
input_tensor = tf.ones(shape=(2, 784))
output_tensor = my_dense(input_tensor)
print(output_tensor.shape)
# Out:
# (2, 32)

# %% [markdown]
# #### 자동 크기 추론: 동적으로 층 만들기

# %%
from tensorflow.keras import layers
layer = layers.Dense(32, activation="relu")

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
model = models.Sequential([
    layers.Dense(32, activation="relu"),
    layers.Dense(32)
])

# %%
model = keras.Sequential([
    SimpleDense(32, activation="relu"),
    SimpleDense(64, activation="relu"),
    SimpleDense(32, activation="relu"),
    SimpleDense(10, activation="softmax")
])

# %% [markdown]
# ### 층에서 모델로

# %% [markdown]
# ### “컴파일” 단계: 학습 과정 설정

# %%
model = keras.Sequential([keras.layers.Dense(1)])
model.compile(optimizer="rmsprop",
              loss="mean_squared_error",
              metrics=["accuracy"])

# %%
model.compile(optimizer=keras.optimizers.RMSprop(),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.BinaryAccuracy()])

# %% [markdown]
# ### 손실 함수 선택하기

# %% [markdown]
# ### fit() 메서드 이해하기

# %% [markdown]
# **넘파이 데이터로 `fit()` 메서드 호출하기**

# %%
history = model.fit(
    inputs,
    targets,
    epochs=5,
    batch_size=128
)
# Out:
# Epoch 1/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - binary_accuracy: 0.4785 - loss: 14.6627
# Epoch 2/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.4563 - loss: 14.3083
# Epoch 3/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.4559 - loss: 13.5823
# Epoch 4/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.4658 - loss: 13.2436
# Epoch 5/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.4798 - loss: 12.6666

# %%
history.history
# Out:
# {'binary_accuracy': [0.4675000011920929,
#   0.4659999907016754,
#   0.4650000035762787,
#   0.46399998664855957,
#   0.4634999930858612],
#  'loss': [14.495392799377441,
#   13.924859046936035,
#   13.44060230255127,
#   12.974480628967285,
#   12.520705223083496]}

# %% [markdown]
# ### 검증 데이터에서 손실과 측정 지표 모니터링하기

# %% [markdown]
# **`validation_data` 매개변수 사용하기**

# %%
model = keras.Sequential([keras.layers.Dense(1)])
model.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.1),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.BinaryAccuracy()])

indices_permutation = np.random.permutation(len(inputs))
shuffled_inputs = inputs[indices_permutation]
shuffled_targets = targets[indices_permutation]

num_validation_samples = int(0.3 * len(inputs))
val_inputs = shuffled_inputs[:num_validation_samples]
val_targets = shuffled_targets[:num_validation_samples]
training_inputs = shuffled_inputs[num_validation_samples:]
training_targets = shuffled_targets[num_validation_samples:]
model.fit(
    training_inputs,
    training_targets,
    epochs=5,
    batch_size=16,
    validation_data=(val_inputs, val_targets)
)
# Out:
# Epoch 1/5
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9051 - loss: 0.6432 - val_binary_accuracy: 0.9983 - val_loss: 0.0281
# Epoch 2/5
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9684 - loss: 0.0702 - val_binary_accuracy: 0.9983 - val_loss: 0.0704
# Epoch 3/5
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9746 - loss: 0.0658 - val_binary_accuracy: 0.9900 - val_loss: 0.0717
# Epoch 4/5
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9610 - loss: 0.0776 - val_binary_accuracy: 0.9983 - val_loss: 0.0358
# Epoch 5/5
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9687 - loss: 0.0635 - val_binary_accuracy: 0.9767 - val_loss: 0.0545

# %% [markdown]
# ### 추론: 훈련한 모델 사용하기

# %%
predictions = model.predict(val_inputs, batch_size=128)
print(predictions[:10])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[ 0.18999135]
#  [ 0.5296265 ]
#  [ 0.81386006]
#  [ 0.5955907 ]
#  [-0.3074181 ]
#  [-0.2583984 ]
#  [ 0.58494794]
#  [ 0.69882154]
#  [-0.09463477]
#  [ 0.00913846]]

# %% [markdown]
# ## 요약
