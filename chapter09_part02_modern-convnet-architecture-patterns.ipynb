# %% [markdown]
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝 2판](https://tensorflow.blog/kerasdl2/)의 예제 코드를 담고 있습니다.
#
# <table align="left">
#     <tr>
#         <td>
#             <a href="https://colab.research.google.com/github/rickiepark/deep-learning-with-python-2nd/blob/main/chapter09_part02_modern-convnet-architecture-patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## 최신 컨브넷 아키텍처 패턴

# %% [markdown]
# ### 모듈화, 계층화 그리고 재사용

# %% [markdown]
# ### 잔차 연결

# %% [markdown]
# **필터 개수가 변경되는 잔차 블록**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
residual = layers.Conv2D(64, 1)(residual)
x = layers.add([x, residual])

# %% [markdown]
# **최대 풀링 층을 가진 잔차 블록**

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
x = layers.MaxPooling2D(2, padding="same")(x)
residual = layers.Conv2D(64, 1, strides=2)(residual)
x = layers.add([x, residual])

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Rescaling(1./255)(inputs)

def residual_block(x, filters, pooling=False):
    residual = x
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    if pooling:
        x = layers.MaxPooling2D(2, padding="same")(x)
        residual = layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
        residual = layers.Conv2D(filters, 1)(residual)
    x = layers.add([x, residual])
    return x

x = residual_block(x, filters=32, pooling=True)
x = residual_block(x, filters=64, pooling=True)
x = residual_block(x, filters=128, pooling=False)

x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 32, 32, 3)    0           ['input_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 32)   896         ['rescaling[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 32)   9248        ['conv2d_6[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)  0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 32)   128         ['rescaling[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 32)   0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 64)   18496       ['add_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_9[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 64)     2112        ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 8, 64)     0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 128)    73856       ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 128)    147584      ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 128)    8320        ['add_3[0][0]']
#
#  add_4 (Add)                    (None, 8, 8, 128)    0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1)            129         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 297,697
# Trainable params: 297,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 배치 정규화

# %% [markdown]
# ### 깊이별 분리 합성곱

# %% [markdown]
# ### Xception 유사 모델에 모두 적용하기

# %% [markdown]
# 캐글에서 dogs-vs-cats 데이터셋을 다운로드하려면 캐글에 가입해야 한 후 생성한 API 키를 사용해야 합니다. 이런 과정이 번거롭다면 다음 명령으로 구글 드라이브에서 직접 다운로드할 수 있습니다.
#
# ```python
# import gdown
# gdown.download(id='18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd', output='dogs-vs-cats.zip')
# ```
#
# 그다음 아래 2개의 코드 셀을 건너 뛰고 바로 `unzip` 명령을 실행하세요.

# %%
# kaggle.json 파일을 업로드하세요.
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1f70d793-d4dc-48eb-ac72-fa637ecc50e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f70d793-d4dc-48eb-ac72-fa637ecc50e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"haesunpark","key":"08f234c75bf1f9cff6991a8a6d5d49ac"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c dogs-vs-cats

# %%
# !unzip -qq dogs-vs-cats.zip
# !unzip -qq train.zip
# Out:
# Downloading dogs-vs-cats.zip to /content
#  99% 805M/812M [00:02<00:00, 300MB/s]
# 100% 812M/812M [00:02<00:00, 296MB/s]

# %%
import os, shutil, pathlib
from tensorflow.keras.utils import image_dataset_from_directory

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)

x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)

for size in [32, 64, 128, 256, 512]:
    residual = x

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    residual = layers.Conv2D(
        size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 44s 434ms/step - loss: 0.7157 - accuracy: 0.5655 - val_loss: 0.6928 - val_accuracy: 0.5120
# Epoch 2/100
# 63/63 [==============================] - 26s 414ms/step - loss: 0.6658 - accuracy: 0.5990 - val_loss: 0.6928 - val_accuracy: 0.5170
# Epoch 3/100
# 63/63 [==============================] - 27s 425ms/step - loss: 0.6237 - accuracy: 0.6465 - val_loss: 0.7032 - val_accuracy: 0.5000
# Epoch 4/100
# 63/63 [==============================] - 27s 428ms/step - loss: 0.6206 - accuracy: 0.6505 - val_loss: 0.6977 - val_accuracy: 0.5000
# Epoch 5/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.5931 - accuracy: 0.6835 - val_loss: 0.6899 - val_accuracy: 0.5380
# Epoch 6/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.5809 - accuracy: 0.6875 - val_loss: 0.7139 - val_accuracy: 0.5000
# Epoch 7/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.5557 - accuracy: 0.7200 - val_loss: 0.7519 - val_accuracy: 0.5380
# Epoch 8/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.5494 - accuracy: 0.7270 - val_loss: 0.5999 - val_accuracy: 0.6640
# Epoch 9/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.5202 - accuracy: 0.7445 - val_loss: 1.1769 - val_accuracy: 0.5350
# Epoch 10/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.5179 - accuracy: 0.7475 - val_loss: 0.7872 - val_accuracy: 0.6220
# Epoch 11/100
# 63/63 [==============================] - 28s 431ms/step - loss: 0.4913 - accuracy: 0.7650 - val_loss: 0.6200 - val_accuracy: 0.6770
# Epoch 12/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.4882 - accuracy: 0.7685 - val_loss: 0.6494 - val_accuracy: 0.7340
# Epoch 13/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.4829 - accuracy: 0.7785 - val_loss: 0.6129 - val_accuracy: 0.6930
# Epoch 14/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.4501 - accuracy: 0.7875 - val_loss: 0.5305 - val_accuracy: 0.7290
# Epoch 15/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.4369 - accuracy: 0.8030 - val_loss: 0.9565 - val_accuracy: 0.6430
# Epoch 16/100
# 63/63 [==============================] - 28s 432ms/step - loss: 0.4434 - accuracy: 0.8025 - val_loss: 0.8992 - val_accuracy: 0.6660
# Epoch 17/100
# 63/63 [==============================] - 27s 432ms/step - loss: 0.4354 - accuracy: 0.7955 - val_loss: 0.6846 - val_accuracy: 0.6930
# Epoch 18/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.3998 - accuracy: 0.8285 - val_loss: 0.6942 - val_accuracy: 0.7070
# Epoch 19/100
# 63/63 [==============================] - 27s 432ms/step - loss: 0.3892 - accuracy: 0.8335 - val_loss: 1.2437 - val_accuracy: 0.5570
# Epoch 20/100
# 63/63 [==============================] - 27s 425ms/step - loss: 0.3760 - accuracy: 0.8280 - val_loss: 3.4449 - val_accuracy: 0.5180
# Epoch 21/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.3636 - accuracy: 0.8345 - val_loss: 0.6256 - val_accuracy: 0.7420
# Epoch 22/100
# 63/63 [==============================] - 28s 433ms/step - loss: 0.3525 - accuracy: 0.8540 - val_loss: 0.5049 - val_accuracy: 0.7710
# Epoch 23/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.3467 - accuracy: 0.8495 - val_loss: 0.4931 - val_accuracy: 0.7890
# Epoch 24/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.3378 - accuracy: 0.8460 - val_loss: 0.4661 - val_accuracy: 0.7940
# Epoch 25/100
# 63/63 [==============================] - 28s 435ms/step - loss: 0.3329 - accuracy: 0.8495 - val_loss: 0.4547 - val_accuracy: 0.8060
# Epoch 26/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.3318 - accuracy: 0.8630 - val_loss: 1.5908 - val_accuracy: 0.6070
# Epoch 27/100
# 63/63 [==============================] - 27s 427ms/step - loss: 0.3147 - accuracy: 0.8585 - val_loss: 0.4504 - val_accuracy: 0.8020
# Epoch 28/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.3263 - accuracy: 0.8570 - val_loss: 0.4382 - val_accuracy: 0.8320
# Epoch 29/100
# 63/63 [==============================] - 26s 416ms/step - loss: 0.2918 - accuracy: 0.8760 - val_loss: 0.4191 - val_accuracy: 0.8400
# Epoch 30/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.2971 - accuracy: 0.8740 - val_loss: 1.9307 - val_accuracy: 0.6570
# Epoch 31/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.2921 - accuracy: 0.8760 - val_loss: 0.5984 - val_accuracy: 0.7330
# Epoch 32/100
# 63/63 [==============================] - 27s 428ms/step - loss: 0.2842 - accuracy: 0.8830 - val_loss: 0.8956 - val_accuracy: 0.7350
# Epoch 33/100
# 63/63 [==============================] - 27s 428ms/step - loss: 0.2710 - accuracy: 0.8920 - val_loss: 0.4399 - val_accuracy: 0.8210
# Epoch 34/100
# 63/63 [==============================] - 28s 436ms/step - loss: 0.2559 - accuracy: 0.8950 - val_loss: 0.5464 - val_accuracy: 0.8130
# Epoch 35/100
# 63/63 [==============================] - 28s 432ms/step - loss: 0.2478 - accuracy: 0.8945 - val_loss: 0.4207 - val_accuracy: 0.8140
# Epoch 36/100
# 63/63 [==============================] - 28s 432ms/step - loss: 0.2599 - accuracy: 0.8935 - val_loss: 0.3733 - val_accuracy: 0.8430
# Epoch 37/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.2379 - accuracy: 0.9085 - val_loss: 0.5696 - val_accuracy: 0.8050
# Epoch 38/100
# 63/63 [==============================] - 27s 425ms/step - loss: 0.2458 - accuracy: 0.8960 - val_loss: 0.7848 - val_accuracy: 0.7380
# Epoch 39/100
# 63/63 [==============================] - 27s 433ms/step - loss: 0.2515 - accuracy: 0.8920 - val_loss: 0.5300 - val_accuracy: 0.8290
# Epoch 40/100
# 63/63 [==============================] - 28s 433ms/step - loss: 0.2255 - accuracy: 0.9060 - val_loss: 0.4354 - val_accuracy: 0.8310
# Epoch 41/100
# 63/63 [==============================] - 28s 438ms/step - loss: 0.2204 - accuracy: 0.9075 - val_loss: 0.4467 - val_accuracy: 0.8420
# Epoch 42/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.2211 - accuracy: 0.9065 - val_loss: 0.5714 - val_accuracy: 0.8320
# Epoch 43/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.2244 - accuracy: 0.9045 - val_loss: 0.5929 - val_accuracy: 0.7640
# Epoch 44/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.2276 - accuracy: 0.9015 - val_loss: 0.3576 - val_accuracy: 0.8550
# Epoch 45/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.2036 - accuracy: 0.9265 - val_loss: 0.4523 - val_accuracy: 0.8520
# Epoch 46/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.2161 - accuracy: 0.9145 - val_loss: 0.4342 - val_accuracy: 0.8390
# Epoch 47/100
# 63/63 [==============================] - 28s 432ms/step - loss: 0.1998 - accuracy: 0.9190 - val_loss: 0.3891 - val_accuracy: 0.8270
# Epoch 48/100
# 63/63 [==============================] - 28s 436ms/step - loss: 0.1985 - accuracy: 0.9215 - val_loss: 0.5412 - val_accuracy: 0.8390
# Epoch 49/100
# 63/63 [==============================] - 28s 435ms/step - loss: 0.1884 - accuracy: 0.9250 - val_loss: 0.4491 - val_accuracy: 0.8370
# Epoch 50/100
# 63/63 [==============================] - 27s 428ms/step - loss: 0.2055 - accuracy: 0.9115 - val_loss: 0.4015 - val_accuracy: 0.8260
# Epoch 51/100
# 63/63 [==============================] - 28s 436ms/step - loss: 0.1924 - accuracy: 0.9190 - val_loss: 0.8215 - val_accuracy: 0.7480
# Epoch 52/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.1930 - accuracy: 0.9165 - val_loss: 0.7379 - val_accuracy: 0.7630
# Epoch 53/100
# 63/63 [==============================] - 27s 427ms/step - loss: 0.1788 - accuracy: 0.9245 - val_loss: 0.3208 - val_accuracy: 0.8880
# Epoch 54/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.1844 - accuracy: 0.9245 - val_loss: 0.4242 - val_accuracy: 0.8400
# Epoch 55/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.1747 - accuracy: 0.9305 - val_loss: 0.5779 - val_accuracy: 0.8150
# Epoch 56/100
# 63/63 [==============================] - 28s 433ms/step - loss: 0.1735 - accuracy: 0.9305 - val_loss: 0.7054 - val_accuracy: 0.7270
# Epoch 57/100
# 63/63 [==============================] - 28s 435ms/step - loss: 0.1695 - accuracy: 0.9350 - val_loss: 0.9904 - val_accuracy: 0.7220
# Epoch 58/100
# 63/63 [==============================] - 28s 432ms/step - loss: 0.1800 - accuracy: 0.9280 - val_loss: 0.3175 - val_accuracy: 0.8780
# Epoch 59/100
# 63/63 [==============================] - 27s 426ms/step - loss: 0.1596 - accuracy: 0.9310 - val_loss: 0.5401 - val_accuracy: 0.8230
# Epoch 60/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.1625 - accuracy: 0.9320 - val_loss: 0.3973 - val_accuracy: 0.8660
# Epoch 61/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.1486 - accuracy: 0.9425 - val_loss: 0.3518 - val_accuracy: 0.8870
# Epoch 62/100
# 63/63 [==============================] - 28s 433ms/step - loss: 0.1477 - accuracy: 0.9365 - val_loss: 0.4951 - val_accuracy: 0.8620
# Epoch 63/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.1465 - accuracy: 0.9395 - val_loss: 0.5101 - val_accuracy: 0.8400
# Epoch 64/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.1326 - accuracy: 0.9450 - val_loss: 0.5947 - val_accuracy: 0.8470
# Epoch 65/100
# 63/63 [==============================] - 27s 426ms/step - loss: 0.1522 - accuracy: 0.9370 - val_loss: 0.3373 - val_accuracy: 0.8660
# Epoch 66/100
# 63/63 [==============================] - 27s 428ms/step - loss: 0.1482 - accuracy: 0.9420 - val_loss: 0.2804 - val_accuracy: 0.8980
# Epoch 67/100
# 63/63 [==============================] - 28s 437ms/step - loss: 0.1384 - accuracy: 0.9455 - val_loss: 0.4554 - val_accuracy: 0.8610
# Epoch 68/100
# 63/63 [==============================] - 28s 437ms/step - loss: 0.1381 - accuracy: 0.9440 - val_loss: 1.1885 - val_accuracy: 0.7760
# Epoch 69/100
# 63/63 [==============================] - 28s 437ms/step - loss: 0.1328 - accuracy: 0.9475 - val_loss: 0.3538 - val_accuracy: 0.8900
# Epoch 70/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.1467 - accuracy: 0.9465 - val_loss: 0.3951 - val_accuracy: 0.8750
# Epoch 71/100
# 63/63 [==============================] - 27s 428ms/step - loss: 0.1383 - accuracy: 0.9480 - val_loss: 0.3656 - val_accuracy: 0.8610
# Epoch 72/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.1321 - accuracy: 0.9515 - val_loss: 0.5243 - val_accuracy: 0.8560
# Epoch 73/100
# 63/63 [==============================] - 27s 426ms/step - loss: 0.1493 - accuracy: 0.9365 - val_loss: 0.8000 - val_accuracy: 0.8040
# Epoch 74/100
# 63/63 [==============================] - 27s 428ms/step - loss: 0.1273 - accuracy: 0.9455 - val_loss: 0.4050 - val_accuracy: 0.8530
# Epoch 75/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.1238 - accuracy: 0.9500 - val_loss: 0.4432 - val_accuracy: 0.8590
# Epoch 76/100
# 63/63 [==============================] - 28s 433ms/step - loss: 0.1336 - accuracy: 0.9490 - val_loss: 0.2949 - val_accuracy: 0.8880
# Epoch 77/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.1219 - accuracy: 0.9445 - val_loss: 0.7136 - val_accuracy: 0.7620
# Epoch 78/100
# 63/63 [==============================] - 27s 430ms/step - loss: 0.1140 - accuracy: 0.9580 - val_loss: 0.4582 - val_accuracy: 0.8730
# Epoch 79/100
# 63/63 [==============================] - 27s 427ms/step - loss: 0.1213 - accuracy: 0.9535 - val_loss: 0.5863 - val_accuracy: 0.8570
# Epoch 80/100
# 63/63 [==============================] - 28s 436ms/step - loss: 0.1345 - accuracy: 0.9435 - val_loss: 0.3763 - val_accuracy: 0.8920
# Epoch 81/100
# 63/63 [==============================] - 27s 424ms/step - loss: 0.1340 - accuracy: 0.9475 - val_loss: 1.2894 - val_accuracy: 0.7110
# Epoch 82/100
# 63/63 [==============================] - 27s 425ms/step - loss: 0.1181 - accuracy: 0.9545 - val_loss: 0.3884 - val_accuracy: 0.8710
# Epoch 83/100
# 63/63 [==============================] - 27s 423ms/step - loss: 0.1209 - accuracy: 0.9550 - val_loss: 0.6110 - val_accuracy: 0.8480
# Epoch 84/100
# 63/63 [==============================] - 28s 432ms/step - loss: 0.1160 - accuracy: 0.9600 - val_loss: 0.8478 - val_accuracy: 0.8150
# Epoch 85/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.1078 - accuracy: 0.9540 - val_loss: 0.3884 - val_accuracy: 0.8960
# Epoch 86/100
# 63/63 [==============================] - 27s 426ms/step - loss: 0.1183 - accuracy: 0.9535 - val_loss: 0.3338 - val_accuracy: 0.8680
# Epoch 87/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.1144 - accuracy: 0.9550 - val_loss: 0.3768 - val_accuracy: 0.8840
# Epoch 88/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.1072 - accuracy: 0.9570 - val_loss: 0.5100 - val_accuracy: 0.8660
# Epoch 89/100
# 63/63 [==============================] - 28s 436ms/step - loss: 0.1111 - accuracy: 0.9585 - val_loss: 0.8556 - val_accuracy: 0.8190
# Epoch 90/100
# 63/63 [==============================] - 28s 436ms/step - loss: 0.0963 - accuracy: 0.9605 - val_loss: 0.7554 - val_accuracy: 0.8300
# Epoch 91/100
# 63/63 [==============================] - 28s 431ms/step - loss: 0.1158 - accuracy: 0.9580 - val_loss: 0.5757 - val_accuracy: 0.8290
# Epoch 92/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.0907 - accuracy: 0.9610 - val_loss: 0.3150 - val_accuracy: 0.8830
# Epoch 93/100
# 63/63 [==============================] - 27s 426ms/step - loss: 0.1079 - accuracy: 0.9600 - val_loss: 0.9646 - val_accuracy: 0.7910
# Epoch 94/100
# 63/63 [==============================] - 27s 429ms/step - loss: 0.1096 - accuracy: 0.9585 - val_loss: 0.3433 - val_accuracy: 0.8750
# Epoch 95/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.0838 - accuracy: 0.9725 - val_loss: 0.2813 - val_accuracy: 0.9080
# Epoch 96/100
# 63/63 [==============================] - 27s 432ms/step - loss: 0.0875 - accuracy: 0.9675 - val_loss: 0.6307 - val_accuracy: 0.8820
# Epoch 97/100
# 63/63 [==============================] - 27s 431ms/step - loss: 0.0987 - accuracy: 0.9680 - val_loss: 0.4387 - val_accuracy: 0.8730
# Epoch 98/100
# 63/63 [==============================] - 28s 437ms/step - loss: 0.0889 - accuracy: 0.9700 - val_loss: 0.5832 - val_accuracy: 0.8690
# Epoch 99/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.0976 - accuracy: 0.9625 - val_loss: 0.6395 - val_accuracy: 0.8330
# Epoch 100/100
# 63/63 [==============================] - 28s 433ms/step - loss: 0.1057 - accuracy: 0.9630 - val_loss: 0.3490 - val_accuracy: 0.8960

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()
